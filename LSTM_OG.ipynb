# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %%
# Load datasets
add=r"C:\Users\adilp\Downloads\INFY Historical Data (2).csv"
infosys_data = pd.read_csv(add, date_parser=True)
print(infosys_data.columns)
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %'], dtype='object')

# %%
infosys_data.rename(columns={'Price': 'Close'}, inplace=True)
def clean_numeric_columns(df, columns):
    for col in columns:
        df[col] = df[col].astype(str).str.replace(',', '').astype(float)
    return df

# %% [markdown]
# # Data Conversion and Normalization

# %%
# Apply to both datasets
infosys_data = clean_numeric_columns(infosys_data, ['Close', 'Open', 'High', 'Low'])
infosys_data['Date'] = pd.to_datetime(infosys_data['Date'],dayfirst=True)
infosys_data.set_index('Date', inplace=True)
infosys_data=infosys_data.sort_index()
scaler = MinMaxScaler(feature_range=(0, 1))
infosys_scaled = scaler.fit_transform(infosys_data[['Close']])
def create_sequences(data, time_step=60):
    X, y = [], []
    for i in range(time_step, len(data)):
        #print(i)
        #print(data[i-time_step:i, 0])
        X.append(data[i-time_step:i, 0])
        y.append(data[i, 0])
        #print(data[i,0])
    return np.array(X), np.array(y)

# %% [markdown]
# # Reshape of Dataset

# %%
X_infy, y_infy = create_sequences(infosys_scaled,3)
x=X_infy.reshape((X_infy.shape[0],X_infy.shape[1],1))
y=y_infy
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=False,shuffle=False)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import KFold

# %% [markdown]
# # Model Building

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (3, 1)))
model.add(Dropout(0.2))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 3, 50)               │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 3, 50)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 3, 60)               │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 3, 60)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 3, 80)               │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 3, 80)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - loss: 0.0035 - mean_absolute_error: 0.0446
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0029 - mean_absolute_error: 0.0404
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0034 - mean_absolute_error: 0.0429
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0037 - mean_absolute_error: 0.0452
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0039 - mean_absolute_error: 0.0478
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0034 - mean_absolute_error: 0.0439
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0029 - mean_absolute_error: 0.0401
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0028 - mean_absolute_error: 0.0392
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0028 - mean_absolute_error: 0.0408
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0031 - mean_absolute_error: 0.0411
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0031 - mean_absolute_error: 0.0420
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0027 - mean_absolute_error: 0.0384
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0028 - mean_absolute_error: 0.0399
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0024 - mean_absolute_error: 0.0364
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0386
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0030 - mean_absolute_error: 0.0409
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0035 - mean_absolute_error: 0.0467
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0033 - mean_absolute_error: 0.0446
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0028 - mean_absolute_error: 0.0405
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0033 - mean_absolute_error: 0.0436
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0027 - mean_absolute_error: 0.0389
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0034 - mean_absolute_error: 0.0428
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0028 - mean_absolute_error: 0.0403
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0037 - mean_absolute_error: 0.0447
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0029 - mean_absolute_error: 0.0399
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0027 - mean_absolute_error: 0.0384
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0026 - mean_absolute_error: 0.0379
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0378
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0030 - mean_absolute_error: 0.0409
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0388
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0028 - mean_absolute_error: 0.0402
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0028 - mean_absolute_error: 0.0396
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0032 - mean_absolute_error: 0.0434
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0399
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0029 - mean_absolute_error: 0.0405
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0029 - mean_absolute_error: 0.0402
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0028 - mean_absolute_error: 0.0404
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0023 - mean_absolute_error: 0.0366
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0030 - mean_absolute_error: 0.0412
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0030 - mean_absolute_error: 0.0409
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0396
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0026 - mean_absolute_error: 0.0378
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0032 - mean_absolute_error: 0.0433
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0025 - mean_absolute_error: 0.0381
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0025 - mean_absolute_error: 0.0377
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0026 - mean_absolute_error: 0.0398
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0028 - mean_absolute_error: 0.0398
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0030 - mean_absolute_error: 0.0404
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0398
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0381
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0047 - mean_absolute_error: 0.0513
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0031 - mean_absolute_error: 0.0409
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0031 - mean_absolute_error: 0.0427
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0026 - mean_absolute_error: 0.0386
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0382
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0392
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0032 - mean_absolute_error: 0.0428
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0023 - mean_absolute_error: 0.0375
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0025 - mean_absolute_error: 0.0370
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0026 - mean_absolute_error: 0.0390
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0027 - mean_absolute_error: 0.0392
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0025 - mean_absolute_error: 0.0387
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0022 - mean_absolute_error: 0.0360
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0027 - mean_absolute_error: 0.0384
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0401
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0031 - mean_absolute_error: 0.0414
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0036 - mean_absolute_error: 0.0449
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0029 - mean_absolute_error: 0.0409
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0026 - mean_absolute_error: 0.0383
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0025 - mean_absolute_error: 0.0376
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0399
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0024 - mean_absolute_error: 0.0377
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0023 - mean_absolute_error: 0.0368
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0024 - mean_absolute_error: 0.0363
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0027 - mean_absolute_error: 0.0390
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0031 - mean_absolute_error: 0.0426
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0026 - mean_absolute_error: 0.0382
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0027 - mean_absolute_error: 0.0392
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0390
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0030 - mean_absolute_error: 0.0417
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0030 - mean_absolute_error: 0.0417
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0025 - mean_absolute_error: 0.0377
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0028 - mean_absolute_error: 0.0392
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0025 - mean_absolute_error: 0.0373
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0030 - mean_absolute_error: 0.0405
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0025 - mean_absolute_error: 0.0380
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0027 - mean_absolute_error: 0.0393
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0386
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0026 - mean_absolute_error: 0.0388
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0026 - mean_absolute_error: 0.0386
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0026 - mean_absolute_error: 0.0387
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0024 - mean_absolute_error: 0.0367
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - mean_absolute_error: 0.0382

# %%
def pred(test,model=model,incerse=True):
    #test=test.reshape(len(test),1)
    prediction=model.predict(test)
    if incerse:
        return scaler.inverse_transform(prediction).reshape(-1)
    return prediction.reshape(-1)
pres=pred(x,model=model,incerse=True)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
y_t=pred(x_test,model,False)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
(r2_score(y_test,y_t))
# Out:
# 0.9267896290346053

# %%
res=pd.DataFrame(data={"Date":infosys_data.index[3:],"Price":infosys_data["Close"].values[3:],"pred":pres})

# %%
plt.figure(figsize=(15,5))
plt.plot(res['Date'],res['Price'],label='Actuall Price in ₹')
plt.plot(res['Date'],res['pred'],label='Predicted Price in ₹')
plt.title("Price Graph")
plt.xlabel('Date')
plt.ylabel('Price ₹')
plt.legend()
plt.show()

# %%
def reshape(x):
    x=x.reshape(1,len(x),1)
    return x

# %%
input_=res.loc[len(res)-3:,['Date','Price']].reset_index(drop=True)

# %%
def norm(test,n=3,scaler=scaler):
    test=np.array(test).reshape(n,1)
    return scaler.transform(test)

# %%
def Output_Gen(input_,n,step=3):
    last=input_.iloc[-1,0]+timedelta(1)
    input=input_.copy()
    print(last)
    for j,i in enumerate(range(n)):
        tes=reshape(norm(input.iloc[i:i+step,1].values))
        print(tes)
        Y=pred(tes)[0]
        print(Y)
        input.loc[j+3]=[last,Y]
        print(last)
        last=last+timedelta(1)
    return input

# %%
output=Output_Gen(input_,7)
# Out:
# 2025-05-21 00:00:00
# [[[0.47673528]
#   [0.43830124]
#   [0.43932274]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1557.2468
# 2025-05-21 00:00:00
# [[[0.43830124]
#   [0.43932274]
#   [0.43504115]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1547.5385
# 2025-05-22 00:00:00
# [[[0.43932274]
#   [0.43504115]
#   [0.42264474]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1541.5923
# 2025-05-23 00:00:00
# [[[0.43504115]
#   [0.42264474]
#   [0.41505221]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1535.3999
# 2025-05-24 00:00:00
# [[[0.42264474]
#   [0.41505221]
#   [0.40714529]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1528.5973
# 2025-05-25 00:00:00
# [[[0.41505221]
#   [0.40714529]
#   [0.39845918]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1521.9271
# 2025-05-26 00:00:00
# [[[0.40714529]
#   [0.39845918]
#   [0.38994219]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1515.1711
# 2025-05-27 00:00:00

# %%
plt.figure(figsize=(15,5))
plt.plot(res['Date'],res['Price'],label='Actuall Price in ₹')
plt.plot(res['Date'],res['pred'],label='Predicted Price in ₹')
plt.plot(output.loc[3:,'Date'],output.loc[3:,'Price'],label='Future Price in ₹')
plt.title("Price Graph")
plt.xlabel('Date')
plt.ylabel('Price ₹')
plt.legend()
plt.grid(True)
plt.show()
